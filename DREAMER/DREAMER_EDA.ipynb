# %%
import scipy.io
import pprint

mat_data = scipy.io.loadmat('DREAMER.mat')
pprint.pprint(mat_data)
# Out:
# {'DREAMER': array([[(array([[array([[(array(['22'], dtype='<U2'), array(['male'], dtype='<U4'), array([[(array([[array([[4390.25641026, 4097.43589744, 4267.69230769, ..., 4512.30769231,
#                                                 4368.71794872, 4287.69230769],
#                                                [4397.43589744, 4095.8974359 , 4248.20512821, ..., 4506.15384615,
#                                                 4272.82051282, 4187.69230769],
#                                                [4391.79487179, 4091.28205128, 4261.02564103, ..., 4494.87179487,
#                                                 4342.56410256, 4256.41025641],
#                                                ...,
#                                                [4392.82051282, 4107.17948718, 4288.71794872, ..., 4532.82051282,
#                                                 4395.38461538, 4307.17948718],
# ...

# %%
import pandas as pd

EEG_0_0_baseline_df = pd.DataFrame(mat_data['DREAMER']['Data'][0][0][0][0]['EEG'][0][0]['baseline'][0][0][0][0])
EEG_0_0_baseline_df.shape
# Out:
# (7808, 14)

# %%
# Plotting 0,0 baseline
channel_names = [value[0] for value in mat_data['DREAMER']['EEG_Electrodes'][0][0][0]]
print(channel_names)
channel_types = ['eeg' for i in range(14)]
print(channel_types)
sfreq = mat_data['DREAMER']['EEG_SamplingRate'][0][0][0][0]
print(sfreq)

import mne
info = mne.create_info(ch_names=channel_names, sfreq=sfreq, ch_types=channel_types)
mne.io.RawArray(EEG_0_0_baseline_df.transpose(), info).compute_psd().plot()
# Out:
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4']
# ['eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg', 'eeg']
# 128
# Creating RawArray with float64 data, n_channels=14, n_times=7808
#     Range : 0 ... 7807 =      0.000 ...    60.992 secs
# Ready.
# Effective window size : 16.000 (s)
# C:\Users\ZYD\AppData\Local\Temp\ipykernel_15768\481123767.py:11: RuntimeWarning: Channel locations not available. Disabling spatial colors.
#   mne.io.RawArray(EEG_0_0_baseline_df.transpose(), info).compute_psd().plot()
# c:\Users\ZYD\anaconda3\envs\eeg\lib\site-packages\mne\viz\utils.py:165: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 1000x350 with 1 Axes>

# %%
EEG_0_0_stimuli_df = pd.DataFrame(mat_data['DREAMER']['Data'][0][0][0][0]['EEG'][0][0]['stimuli'][0][0][0][0])
EEG_0_0_stimuli_df.shape
# Out:
# (25472, 14)

# %%
mne.io.RawArray(EEG_0_0_stimuli_df.transpose(), info).compute_psd().plot()
# Out:
# Creating RawArray with float64 data, n_channels=14, n_times=25472
#     Range : 0 ... 25471 =      0.000 ...   198.992 secs
# Ready.
# Effective window size : 16.000 (s)
# C:\Users\ZYD\AppData\Local\Temp\ipykernel_15768\1251559825.py:1: RuntimeWarning: Channel locations not available. Disabling spatial colors.
#   mne.io.RawArray(EEG_0_0_stimuli_df.transpose(), info).compute_psd().plot()
# c:\Users\ZYD\anaconda3\envs\eeg\lib\site-packages\mne\viz\utils.py:165: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 1000x350 with 1 Axes>
